# %%
#1.1 Cálculo Básico
print(2 + 3 * 6)
print((2 + 3) * 6)
print(2**8)
print(23 // 7)
print(23 % 7)
print((5 - 1) * ((7 + 1) / (3 - 1)))
# Out:
# 20
# 30
# 256
# 3
# 2
# 16.0

# %%
#1.2 Operadores Asignación
greeting = 'Hello'
greeting += 'world!' 
print(greeting)

number = 1 
number += 1 
print(number)

my_list = ['item']
my_list *= 3
print(my_list)

# %%
# 1.3 Variables
# mal
my variable = 'Hello'
# bien
var = 'Hello’
# mal
# %$@variable = 'Hello'
# bien
my_var = 'Hello'
# bien
my_var_2 = 'Hello’
# mal
23_var = 'hello'
# Out:
#   Cell In[3], line 4
#     var = 'Hello’
#           ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
# 1.4 Cases (Formas de Nombar)
variableCamelCase = 'No'
VariablePascalCase = 'Clases'
varible-kebab-case = 'No'
variable_snake_case = 'Si'

# %%
# 1.5 Comentarios
# comentario de una línea
variable = 1 # comentario de código
"""
comentario
de
varias
lineas
"""

# %%
# 1.6 print()
print('Hello World!')

a = 1
print('Hello World!', a)

phrase = ['printed', 'with', 'a', 'dash', \
'in', 'between']

for word in phrase:
    print(word, end='-')

print('cats', 'dogs', 'mice', sep=',')

# %%
# 1.7 input()
# NO FUNCIONA AQUÍ
'''
print('What is your name?')
my_name = input()

print('Hi, {}'.format(my_name))
'''

# %%
# 1.8 len()

a = len('hello')
print(a)

a = len(['cat', 3, 'dog'])
print(a)

# %%
# 1.9 Conversión de tipos
print(str(29))
print(str(-3.14))
print(int('11'))
print(float('3.14'))

# %%
# 1.10 Comparación
print( 42 == 42)
print( 40 == 42)

print('hello' == 'hello')
print('hello' == 'Hello')

print('dog' != 'cat')

print(42 == 42.0)
print(42 === 42.0)
print(42 == '42')

# %%
# 1.11 Comparación Lógica

print(4 < 5) and (5 < 6)

print(4 < 5) and (9 < 6)

print(1 == 2) or (2 == 2)

print( (2 + 2 == 4 and not ((2 + 2) == 5) and (2 * 2 == 2 +2)))

# %%
# 1.12 Clausula If

name = 'Debora'

if name == 'Debora':
    print('Hi, Debora')

if name != 'George':
    print('You are not George')

# %%
# 1.13 Bucle While
spam = 0
while spam < 5:
    print('Hell0, World.')
    spam = spam + 1

# %%
# 1.14 Bucle For
pets = ['Bella', 'Milo', 'Loki']
for pet in pets:
    print(pet)

# %%
# 1.14 Bucle For
for i in range(5):
    print(f"Will stop at 5! or 4 {{i}}")

# %%
# 1.15 Strings
a = '''Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''

print(a[1])

print(len(a))

for x in "banana":
    print(x)

print('dolor' in a)

print('dolor' not in txt)

# %%
# 1.16 Funciones y Argumentos
def say_hello(name):
    print(f"Hello {name}")

say_hello('Carlos')

say_hello('Daniel')

# %%
# 1.16 Funciones y Argumentos
def say_hi(name, greeting):
    print(f"{greeting} {name}")

say_hi('John', 'Hello')
